# %% [markdown]
# ## Import libraries and dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("creditcard_dataset_1.csv")
x=data.iloc[:,0:-1]
y=data.iloc[:,-1]

# %% [markdown]
# ## Pre-processing and Analyzing

# %%
x.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
x.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
valid = data[data['Class']==0]
fraud = data[data['Class']==1]
percent_fraud = fraud.shape[0]/x.shape[0]
print("Percentage of fraudulent transactions is: " + str(format(percent_fraud*100,'.3f')) + "%")
# Out:
# Percentage of fraudulent transactions is: 0.173%

# %%
correlation_matrix = data.corr()
fig = plt.figure(figsize=(8,8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
valid['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ### Splitting into train-test set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8, stratify=y)

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train,y_train)
x_test=sc.transform(x_test)

# %% [markdown]
# ## Building the Model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_predict = knn.predict(x_test)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import accuracy_score , recall_score

n_error = (y_predict!=y_test).sum()
acc = accuracy_score(y_test,y_predict)
recall = recall_score(y_test,y_predict)

print("The total number of errors in our predictions are {:.3f} out of {}".format(n_error,y_test.shape[0]))
print("The accuracy of our model is {:.3f} %.".format(acc*100))
print("The recall score of our model is {:.3f}.".format(recall))
# Out:
# The total number of errors in our predictions are 22.000 out of 56962
# The accuracy of our model is 99.961 %.
# The recall score of our model is 0.816.

# %%
from sklearn.metrics import confusion_matrix

Labels=['Normal','Fraud']
conf_mat = confusion_matrix(y_test,y_predict)
sns.heatmap(conf_mat,annot=True,cmap='coolwarm', xticklabels=Labels, yticklabels=Labels)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')
